# %% [markdown]
# ## An example notebook of how to use (heat)maps with Python

# %% [markdown]
# In this notebook you will see an example of using maps. The data used is openly available at https://www.opendatani.gov.uk. The goal of this example is to plot a heatmap of trees with over 90cm diameter in Belfast and with their condition being either "Dead" or "Poor".

# %%
# First import pandas to be able to read csv-format data
import pandas as pd

# %%
data = pd.read_csv('https://www.belfastcity.gov.uk/getmedia/262a1f01-f219-4780-835e-7a833bdd1e1c/odTrees.csv',low_memory=False)

data.head(10)
# Out:
#    TYPEOFTREE     SPECIESTYPE                         SPECIES           AGE  \
# 0    ParkTree          Cherry       Prunus cerasifera 'Nigra'  Young Mature
# 1    ParkTree           Maple             Acer pseudoplatanus         Young
# 2    ParkTree          Poplar                    Populus alba         Young
# 3    ParkTree           Mixed                 Mixed broadleaf         Young
# 4    ParkTree            Pine                     Pinus nigra  Young Mature
# 5    ParkTree             Oak                   Quercus robur  Fully Mature
# 6    ParkTree  Sweet Chestnut                 Castanea sativa        Mature
# 7  StreetTree           Beech                 Fagus sylvatica        Mature
# 8  StreetTree            Pear  Pyrus calleryana 'Chanticleer'      Juvenile
# 9    ParkTree           Beech                 Fagus sylvatica        Mature
#
#       DESCRIPTION TREESURROUND  VIGOUR CONDITION  DIAMETERinCENTIMETRES  \
# 0     Semi-Mature       Shrubs     Low      Poor                     70
# 1  Juvenile/Young       Shrubs  Normal      Fair                     32
# 2  Juvenile/Young        Grass  Normal      Fair                    -29
# 3  Juvenile/Young       Shrubs  Normal      Fair                     21
# 4     Semi-Mature        Grass  Normal      Poor                     47
# 5    Fully Mature  Bare Ground     NaN      Fair                     97
# 6          Mature     Woodland  Normal      Poor                     90
# 7          Mature       Tarmac     Low      Fair                     96
# 8  Heavy Standard       Tarmac     Low      Poor                      7
# 9          Mature  Bare Ground     Low      Fair                     84
#
#    SPREADRADIUSinMETRES  TREELOCATIONX  TREELOCATIONY  LONGITUDE   LATITUDE  \
# 0                     5      330667.06      367682.71  -5.981870  54.540617
# 1                     5      330625.38      367704.99  -5.982504  54.540827
# 2                     2      337100.35      372798.80  -5.880162  54.584845
# 3                     4      333987.99      372339.02  -5.928477  54.581551
# 4                     7      332251.15      371468.65  -5.955712  54.574194
# 5                    11      336850.82      373056.95  -5.883899  54.587230
# 6                     7      336866.43      373059.67  -5.883656  54.587250
# 7                     7      338437.44      374567.48  -5.858663  54.600358
# 8                     1      331649.26      375492.53  -5.963210  54.610474
# 9                     9      330666.84      367743.78  -5.981846  54.541165
#
#   TREETAG  TREEHEIGHTinMETRES
# 0     292                 8.0
# 1     305                14.0
# 2      29                12.0
# 3    1022                12.0
# 4     115                13.0
# 5     190                20.0
# 6     194                16.0
# 7     NaN                18.0
# 8       0                 0.0
# 9     415                26.0

# %%
# Folium module includes maps, and HeatMap is needed to generate a heatmap
import folium
from folium.plugins import HeatMap
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2200/2752298908.py in <module>
#       1 # Folium module includes maps, and HeatMap is needed to generate a heatmap
# ----> 2 import folium
#       3 from folium.plugins import HeatMap
#
# ModuleNotFoundError: No module named 'folium'

# %%
# Choose the relevant data
diam = data[(data['DIAMETERinCENTIMETRES'] > 90) & ((diam['CONDITION'] == 'Dead') | (data['CONDITION'] == 'Poor'))]

# %%
# Folium's HeatMap-function requires the coordinates to be pairs of coordinates in a list: [[LAT,LON]]
coords = []

# Let's iterate thru the dataframe that has the data we want and append the coordinates to coords-list
for index, row in diam.iterrows():
    coords.append([row['LATITUDE'],row['LONGITUDE']])

# %%
# m is now a folium.Map, with center being at [54.5,-5.85] (Belfast), tiles changes the mapstyle. With world_copy_jump = True 
# the map is scrollable all the way around and the data moves with it as well
# control_scale = True shows the scale at the bottom left
m = folium.Map([54.5, -5.85], tiles='openstreetmap', zoom_start=10, world_copy_jump = True, control_scale = True)

# Generates the heatmap, with each node being radius 15, and a list of coordinates being the first argument.
# add_to(map) tells you to which map the heatmap layer is going to be added to
HeatMap(coords, radius = 15).add_to(m)

m
